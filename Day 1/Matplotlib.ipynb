# %%
pip show matplotlib
# Out:
# Name: matplotlib
# Version: 3.0.0
# Summary: Python plotting package
# Home-page: http://matplotlib.org
# Author: John D. Hunter, Michael Droettboom
# Author-email: matplotlib-users@python.org
# License: BSD
# Location: c:\users\administrator\appdata\local\programs\python\python36-32\lib\site-packages
# Requires: pyparsing, python-dateutil, cycler, kiwisolver, numpy
# Required-by: seaborn
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# #### 1. Line Plot

# %% [markdown]
# #### Lets consider 2 list days and temperature

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,46]

# %%
plt.plot(x,y,marker='+',color='red',markersize=16)
plt.xlabel(" Day ")
plt.ylabel("Temperature")
plt.title("Day wise temperature")
# Out:
# Text(0.5, 1.0, 'Day wise temperature')

# %% [markdown]
# #### 2. Scatter Plot

# %% [markdown]
# Pandas is a software library written for the Python programming language for data manipulation and analysis.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv("C:/Users/Administrator/Desktop/pythoncc/datasets/Road_Accidents_2017-Annexure_ Tables_1.csv")

# %%
data
# Out:
#     Years  Total Number of Road Accidents (in numbers)  \
# 0    1970                                       114100
# 1    1980                                       153200
# 2    1990                                       282600
# 3    1994                                       325864
# 4    1995                                       351999
# 5    1996                                       371204
# 6    1997                                       373671
# 7    1998                                       385018
# 8    1999                                       386456
# 9    2000                                       391449
# 10   2001                                       405637
# 11   2002                                       407497
# 12   2003                                       406726
# 13   2004                                       429910
# 14   2005                                       439255
# 15   2006                                       460920
# 16   2007                                       479216
# 17   2008                                       484704
# 18   2009                                       486384
# 19   2010                                       499628
# 20   2011                                       497686
# 21   2012                                       490383
# 22   2013                                       486476
# 23   2014                                       489400
# 24   2015                                       501423
# 25   2016                                       480652
# 26   2017                                       464910
#
#     Total Number of Persons Killed (in numbers)  \
# 0                                         14500
# 1                                         24000
# 2                                         54100
# 3                                         64463
# 4                                         70781
# 5                                         74665
# 6                                         76977
# 7                                         79919
# 8                                         81966
# 9                                         78911
# 10                                        80888
# 11                                        84674
# 12                                        85998
# 13                                        92618
# 14                                        94968
# 15                                       105749
# 16                                       114444
# 17                                       119860
# 18                                       125660
# 19                                       134513
# 20                                       142485
# 21                                       138258
# 22                                       137572
# 23                                       139671
# 24                                       146133
# 25                                       150785
# 26                                       147913
#
#     Total Number of Persons Injured (in numbers)  \
# 0                                          70100
# 1                                         109100
# 2                                         244100
# 3                                         311500
# 4                                         323200
# 5                                         369502
# 6                                         378361
# 7                                         390674
# 8                                         375051
# 9                                         399265
# 10                                        405216
# 11                                        408711
# 12                                        435122
# 13                                        464521
# 14                                        465282
# 15                                        496481
# 16                                        513340
# 17                                        523193
# 18                                        515458
# 19                                        527512
# 20                                        511394
# 21                                        509667
# 22                                        494893
# 23                                        493474
# 24                                        500279
# 25                                        494624
# 26                                        470975
#
#     Population of India (in thousands)  \
# 0                             539000.0
# 1                             673000.0
# 2                             835000.0
# 3                             904000.0
# 4                             924359.0
# 5                             941579.0
# 6                             959792.0
# 7                             978081.0
# 8                             996130.0
# 9                            1014825.0
# 10                           1028610.0
# 11                           1045547.0
# 12                           1062388.0
# 13                           1079117.0
# 14                           1095722.0
# 15                           1112186.0
# 16                           1128521.0
# 17                           1144734.0
# 18                           1160813.0
# 19                           1176742.0
# 20                           1210193.4
# 21                           1208116.0
# 22                           1223581.0
# 23                           1238887.0
# 24                           1254019.0
# 25                           1268961.0
# 26                           1283601.0
#
#     Total Number of Registered Motor Vehicles (in thousands)  \
# 0                                              1401.0
# 1                                              4521.0
# 2                                             19152.0
# 3                                             27660.0
# 4                                             30295.0
# 5                                             33786.0
# 6                                             37332.0
# 7                                             41368.0
# 8                                             44875.0
# 9                                             48857.0
# 10                                            54991.0
# 11                                            58924.0
# 12                                            67007.0
# 13                                            72718.0
# 14                                            81502.0
# 15                                            89618.0
# 16                                            96707.0
# 17                                           105353.0
# 18                                           114951.0
# 19                                           127746.0
# 20                                           141865.6
# 21                                           159490.6
# 22                                           181508.0
# 23                                           190704.0
# 24                                           210023.0
# 25                                           230031.0
# 26                                                NaN
#
#     Road Length (in kms)  Number of Accidents per Lakh Population  \
# 0              1188728.0                                     21.2
# 1              1491873.0                                     22.8
# 2              1983867.0                                     33.8
# 3              2890950.0                                     36.0
# 4              2975035.0                                     38.1
# 5              3202515.0                                     39.4
# 6              3298788.0                                     38.9
# 7              3228356.0                                     39.4
# 8              3296650.0                                     38.8
# 9              3316078.0                                     38.6
# 10             3373520.0                                     39.4
# 11             3426603.0                                     39.0
# 12             3528654.0                                     38.3
# 13             3621507.0                                     39.8
# 14             3809156.0                                     40.1
# 15             3880651.0                                     41.4
# 16             4016401.0                                     42.5
# 17             4109592.0                                     42.3
# 18             4471510.0                                     41.9
# 19             4582439.0                                     42.5
# 20             4676838.0                                     41.1
# 21             4865394.0                                     40.6
# 22             5231922.0                                     39.8
# 23             5402486.0                                     39.5
# 24             5472144.0                                     40.0
# 25             5603293.0                                     37.9
# 26                   NaN                                     36.2
#
#     Number of Accidents per Ten Thousand Vehicles  \
# 0                                           814.4
# 1                                           338.9
# 2                                           147.6
# 3                                           117.8
# 4                                           116.2
# 5                                           109.9
# 6                                           100.1
# 7                                            93.1
# 8                                            86.1
# 9                                            80.1
# 10                                           73.8
# 11                                           69.2
# 12                                           60.7
# 13                                           59.1
# 14                                           53.9
# 15                                           51.4
# 16                                           49.6
# 17                                           46.0
# 18                                           42.3
# 19                                           39.1
# 20                                           35.1
# 21                                           30.7
# 22                                           26.8
# 23                                           25.7
# 24                                           23.9
# 25                                           20.9
# 26                                            NaN
#
#     Number of Accidents per Ten Thousand Kms of Roads  \
# 0                                               959.8
# 1                                              1026.9
# 2                                              1424.5
# 3                                              1127.2
# 4                                              1183.2
# 5                                              1159.1
# 6                                              1132.8
# 7                                              1192.6
# 8                                              1172.3
# 9                                              1180.5
# 10                                             1202.4
# 11                                             1189.2
# 12                                             1152.6
# 13                                             1187.1
# 14                                             1153.2
# 15                                             1187.7
# 16                                             1193.1
# 17                                             1179.4
# 18                                             1087.7
# 19                                             1090.3
# 20                                             1064.2
# 21                                             1007.9
# 22                                              929.8
# 23                                              905.9
# 24                                              916.3
# 25                                              857.8
# 26                                                NaN
#
#     Number of Persons Killed Per Lakh Population  \
# 0                                            2.7
# 1                                            3.6
# 2                                            6.5
# 3                                            7.1
# 4                                            7.7
# 5                                            7.9
# 6                                            8.0
# 7                                            8.2
# 8                                            8.2
# 9                                            7.8
# 10                                           7.9
# 11                                           8.1
# 12                                           8.1
# 13                                           8.6
# 14                                           8.7
# 15                                           9.5
# 16                                          10.1
# 17                                          10.5
# 18                                          10.8
# 19                                          11.4
# 20                                          11.8
# 21                                          11.4
# 22                                          11.2
# 23                                          11.3
# 24                                          11.7
# 25                                          11.9
# 26                                          11.5
#
#     Number of Persons Killed Per Ten Thousand Vehicles  \
# 0                                               103.5
# 1                                                53.1
# 2                                                28.2
# 3                                                23.3
# 4                                                23.4
# 5                                                22.1
# 6                                                20.6
# 7                                                19.3
# 8                                                18.3
# 9                                                16.2
# 10                                               14.7
# 11                                               14.4
# 12                                               12.8
# 13                                               12.7
# 14                                               11.7
# 15                                               11.8
# 16                                               11.8
# 17                                               11.4
# 18                                               10.9
# 19                                               10.5
# 20                                               10.0
# 21                                                8.7
# 22                                                7.6
# 23                                                7.3
# 24                                                7.0
# 25                                                6.6
# 26                                                NaN
#
#     Number of Persons Killed per Ten Thousand Kms of Roads  \
# 0                                               122.0
# 1                                               160.9
# 2                                               272.7
# 3                                               223.0
# 4                                               237.9
# 5                                               233.1
# 6                                               233.3
# 7                                               247.6
# 8                                               248.6
# 9                                               238.0
# 10                                              239.8
# 11                                              247.1
# 12                                              243.7
# 13                                              255.7
# 14                                              249.3
# 15                                              272.5
# 16                                              284.9
# 17                                              291.7
# 18                                              281.0
# 19                                              293.5
# 20                                              304.7
# 21                                              284.2
# 22                                              262.9
# 23                                              258.5
# 24                                              267.0
# 25                                              269.1
# 26                                                NaN
#
#     Number of Persons Injured per Lakh Population  \
# 0                                            13.0
# 1                                            16.2
# 2                                            29.2
# 3                                            34.5
# 4                                            35.0
# 5                                            39.2
# 6                                            39.4
# 7                                            39.9
# 8                                            37.7
# 9                                            39.3
# 10                                           39.4
# 11                                           39.1
# 12                                           41.0
# 13                                           43.0
# 14                                           42.5
# 15                                           44.6
# 16                                           45.5
# 17                                           45.7
# 18                                           44.4
# 19                                           44.8
# 20                                           42.3
# 21                                           42.2
# 22                                           40.4
# 23                                           39.8
# 24                                           39.9
# 25                                           39.0
# 26                                           36.7
#
#     Number of Persons Injured Per Ten Thousand Vehicles  \
# 0                                               500.4
# 1                                               241.3
# 2                                               127.5
# 3                                               112.6
# 4                                               106.7
# 5                                               109.4
# 6                                               101.4
# 7                                                94.4
# 8                                                83.6
# 9                                                81.7
# 10                                               73.7
# 11                                               69.4
# 12                                               64.9
# 13                                               63.9
# 14                                               57.1
# 15                                               55.4
# 16                                               53.1
# 17                                               49.7
# 18                                               44.8
# 19                                               41.3
# 20                                               36.0
# 21                                               32.0
# 22                                               27.3
# 23                                               25.9
# 24                                               23.8
# 25                                               21.5
# 26                                                NaN
#
#     Number of Persons Injured Per Ten Thousand Kms of Roads
# 0                                               589.7
# 1                                               731.3
# 2                                              1230.4
# 3                                              1077.5
# 4                                              1086.4
# 5                                              1153.8
# 6                                              1147.0
# 7                                              1210.1
# 8                                              1137.7
# 9                                              1204.0
# 10                                             1201.2
# 11                                             1192.8
# 12                                             1233.1
# 13                                             1282.7
# 14                                             1221.5
# 15                                             1279.4
# 16                                             1278.1
# 17                                             1273.1
# 18                                             1152.8
# 19                                             1151.2
# 20                                             1093.5
# 21                                             1047.5
# 22                                              945.9
# 23                                              913.4
# 24                                              914.2
# 25                                              882.7
# 26                                                NaN

# %%
plt.scatter(df.Years,df['Total Number of Persons Killed (in numbers)'],marker=".")
plt.ylabel("No of people Died")
plt.xlabel("Year")
plt.title("People Died in Accident respect to Years in India")
plt.grid()

# %% [markdown]
# ##### 3. Bar Chart

# %% [markdown]
# - bar chart is basically used for see the comparision between various parameters

# %%
company=["TCS","Infy","LTI","PSL"]
revenue=[400,370,90,160]

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(company,revenue,label="Revenue")
plt.xlabel("Company")
plt.ylabel("Revenue in Bill. Dollars")
plt.title("Graph for company vs Revenue")
plt.legend()

# %% [markdown]
# ##### 4. Pie Charts

# %% [markdown]
# - it used to plot the graph with percentages for each criteria. for ex company expenses

# %%
company_expenses=[100,60,40,20,80]
expense_data=["emp_sal","IF Devlopment","Food Expenses","Travelling Allow","prizes"]

# %%
plt.pie(company_expenses,labels=expense_data,startangle=90, shadow=True,autopct='%1.2f%%',radius=1.5,explode=[0,0,0.1,0.2,0.2])
plt.savefig("C:/Users/Administrator/Desktop/TCE_expenses.png")
